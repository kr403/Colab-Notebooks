# %%
Z1 = [8,7,5]
U1 = []
for i in range(20):
    Z1.append((3*(Z1[-1])**2 + 1*Z1[-2] + 0*Z1[-3]) % 15)
    U1.append(Z1[-1]/15)
print(U1)

Z2 = [2,4]
U2 = []
for i in range(20):
    Z2.append((8*(Z2[-1])**3 + 3*Z2[-2] + 0) % 17)
    U2.append(Z2[-1]/17)
print(U2)

rv = []
ru = []
for i in range(20):
    rv.append((2*Z1[i]+7*Z2[i])%17)
    ru.append(rv[-1]/17)
print(ru)
# Out:
# [0.4666666666666667, 0.13333333333333333, 0.26666666666666666, 0.3333333333333333, 0.26666666666666666, 0.5333333333333333, 0.06666666666666667, 0.7333333333333333, 0.26666666666666666, 0.9333333333333333, 0.4666666666666667, 0.7333333333333333, 0.6666666666666666, 0.7333333333333333, 0.8666666666666667, 0.5333333333333333, 0.6666666666666666, 0.5333333333333333, 0.4666666666666667, 0.3333333333333333]
# [0.47058823529411764, 0.6470588235294118, 0.7647058823529411, 0.8235294117647058, 0.5882352941176471, 0.058823529411764705, 0.23529411764705882, 0.29411764705882354, 0.5294117647058824, 0.9411764705882353, 0.11764705882352941, 0.5882352941176471, 0.9411764705882353, 0.29411764705882354, 0.6470588235294118, 0.23529411764705882, 0.058823529411764705, 0.17647058823529413, 0.8823529411764706, 0.7647058823529411]
# ...
