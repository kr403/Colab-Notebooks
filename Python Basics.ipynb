# %% [markdown]
# Output and Input

# %%
print("Hello, Python!")
# Out:
# Hello, Python!

# %%
print("CSI" + str(342))
# Out:
# CSI342

# %%
input_num = input('Number?: ')
input_num = int(input_num)
print(int(input_num/2))

# %% [markdown]
# Type of variables

# %%
# https://www.w3schools.com/python/python_datatypes.asp
s = "234"
a = int(s)
print(type(a))
b = float(s)
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>

# %%
a = 2
print(type(a))
a = "two"
print(type(a))
# Out:
# <class 'int'>
# <class 'str'>

# %%
print(5//2)
i = 2
i += 1
# Out:
# 2

# %% [markdown]
# Comment

# %%
# single line comment
'''
this 
is 
a multi-line
comment
'''
# Out:
# '\nthis \nis \na multi-line\ncomment\n'

# %% [markdown]
# List, Tuple, Dictionary, set

# %%
# https://www.geeksforgeeks.org/differences-and-applications-of-list-tuple-set-and-dictionary-in-python/
# LIST []
# TUPLE () - IT CAN NOT BE CHANGED; READ-ONLY
# DICTIONARY
# SET {} - Set will not allow duplicate elements

# %%
tup1 = (12, 34.56)
list1 = [1,5,8]

# temp = tup1 + list1 #this action is not possible

# %%
nums = [1,2,3, "four"] # 99, 88, 17, 23
nums.append(3)
nums.append(5)
print(nums)
print(nums[0])
print(nums[0:2]) #start:end ==> start ... end-1
#nums.extend([3,5])
print(nums[0:-3])
nums.reverse()
print(nums)
#list[start_index:end_index+1]
# Out:
# [1, 2, 3, 'four', 3, 5]
# 1
# [1, 2]
# [1, 2, 3]
# [5, 3, 'four', 3, 2, 1]

# %%
nums = [[1,2,3], [2,3,4]]
print(nums)
# Out:
# [[1, 2, 3], [2, 3, 4]]

# %%
names = []
names.append('a')
names.append('b')
names.append('a')
names.append('c')
print(names)
# Out:
# ['a', 'b', 'a', 'c']

# %%
names.remove('a')
print(names)
# Out:
# ['b', 'a', 'c']

# %%
names.pop(1)
print(names)
# Out:
# ['b', 'c']

# %%
print(names)
names.extend(['x','y'])
print(names)
# Out:
# ['b', 'c']
# ['b', 'c', 'x', 'y']

# %%
names = ['d', 'b', 'c', 'a', 'e']
# print(names[0:-1])
names.sort()
print(names)

# names[start_idx: end_index+1]
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
nums = [1,5,2,8,-4,10000,0,-85]

nums.sort()
print(nums)
# Out:
# [-85, -4, 0, 1, 2, 5, 8, 10000]

# %%
coord = (1,2)
x = coord[0]
print(x)
# Out:
# 1

# %%
names = ['d', 'b', 'c', 'a', 'd']
nameset = set(names)
print(nameset)
st = {1, 2, 3}
# Out:
# {'a', 'd', 'c', 'b'}

# %%
###list

# %%
list = [ 'abcd', 786 , 2.23, 'john', 70.2 ]
tinylist = [123, 'john']

print (list )        # Prints complete list
print (list[0])      # Prints first element of the list
print (list[1:3] )    # Prints elements starting from 2nd till 3rd 
print (list[2:] ) # Prints elements starting from 3rd element
print(list[:3])
print("Different indexign")
print(list[-1]) #Prints the last element

print (tinylist * 2)  # Prints list two times
print (list + tinylist) # Prints concatenated lists
# Out:
# ['abcd', 786, 2.23, 'john', 70.2]
# abcd
# [786, 2.23]
# [2.23, 'john', 70.2]
# ['abcd', 786, 2.23]
# Different indexign
# 70.2
# [123, 'john', 123, 'john']
# ['abcd', 786, 2.23, 'john', 70.2, 123, 'john']

# %%
#(key, value)
# HashMap <Integer,String> map = new HashMap<Integer,String>();
# map.put(1,'meena')
# map.put(2,'raju')
roll_name = {'qqq': 101, 2: 'bbb', 10001: 'zzz'}
if 'qqq' in roll_name.keys():
    print('success')
else:
    print('no key')
    
cartoon = {1:'Meena',2:'Raju',3:'Mithu'}
print(cartoon.values())
cartoon[1]
# Out:
# success
# dict_values(['Meena', 'Raju', 'Mithu'])
# 'Meena'

# %%
# Set 
s = set() 
  
# Adding element into set 
s.add(5) 
s.add(10) 
print("Adding 5 and 10 in set", s) 
  
s.add(5)

print("Set contents adding new 5 ->",s)

# Removing element from set 
s.remove(5) 
print("Removing 5 from set", s) 
print()
# Out:
# Adding 5 and 10 in set {10, 5}
# Set contents -> {10, 5}
# Removing 5 from set {10}

# %% [markdown]
# Python Loops

# %%
# for(int i = 0; i<=10; i++){
# }

for roll in range(1,5):
    print(roll)

# nums = [10, 17, 21]
# for num in nums:
#     print(num)
# Out:
# 1
# 2
# 3
# 4

# %%
x = range(1, 10)
# print(x)
# Out:
# range(1, 10)

# %%
for i in range(5, 12):
    print(i)
    if (i%3==0):
        print("Divisible by 3")
    elif (i%5==0):
        print("Divisible by 5")
    else:
        print("Not divisible by 3 or 5")
# Out:
# 5
# Divisible by 5
# 6
# Divisible by 3
# 7
# Not divisible by 3 or 5
# 8
# Not divisible by 3 or 5
# 9
# Divisible by 3
# 10
# Divisible by 5
# 11
# Not divisible by 3 or 5

# %%
# While Loop
i = 0
while (i <= 18):
    i += 2
    print(i)
    if (i==8):
        break
# Out:
# 2
# 4
# 6
# 8

# %% [markdown]
# Function

# %%
# https://www.w3schools.com/python/python_functions.asp
def func_name(a, b):
    print(a+str(2))
    return b/2,b*2

x = func_name('CSI', 342)
print(x)
# Out:
# CSI2
# (171.0, 684)

# %%
# Recursive Function

# 4! = 4*3!
# fact(n) = n * fact(n-1)

def fact(n):
    if(n==1):
        return 1
    return n*fact(n-1)
fact(4)
# Out:
# 24

# %% [markdown]
# File Handling

# %%
f = open('dummy.txt', 'w') #w, r, a
f.write('First line\n')
f.close()

# %%
f = open('dummy.txt', 'a')
f.write('Second line\1n')
f.close()

# %%
with open('dummy.txt', 'r') as f:
     lines = f.readlines()

print(lines[0])
# Out:
# First line

# %% [markdown]
# Exceptions

# %%
a = [1,2,3]
try:
    a[3] = 100
except:
    print("Index doesn't exist")
# Out:
# Index doesn't exist

# %%
try:
  print(foo)
except NameError:
  print("Variable foo is not defined")
except:
  print("Something else went wrong")
# Out:
# Variable x is not defined

# %% [markdown]
# Numpy

# %%
# https://www.w3schools.com/python/numpy_intro.asp

import numpy as np
np.random.seed()
print(np.random.randint(5))
print(np.random.rand())
print(np.random.rand())
# Out:
# 2
# 0.5596906699918266
# 0.5036798157210537

# %%
nums = [[1,2,3,4], [2,3,4,5]]
np_nums = np.array(nums)
print(np_nums)
print((np_nums[0:1, 1:3]))
# Out:
# [[1 2 3 4]
#  [2 3 4 5]]
# [[2 3]]

# %%
np_nums.reshape(3,2) #(4,2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-6753d463df8c> in <module>()
# ----> 1 np_nums.reshape(3,2) #(4,2)
#
# ValueError: cannot reshape array of size 8 into shape (3,2)

# %% [markdown]
# Matplotlib

# %%
#Matplotlib

import numpy as np
import matplotlib.pyplot as plt
import math

# Compute the x and y coordinates for points on a sine curve
x = np.arange(0, 4 * np.pi, 0.1) # [0, 0.1, 0.2, 0.3, ... 3*3.1416]
#y = np.sin(x)  #uncomment this and see the magic
y = np.sin(x) # [0, 0.2, 0.4, 0.6, ... 2*3*3.1416 ]

# Plot the points using matplotlib
plt.plot(x, y)
plt.show()  # You must call plt.show() to make graphics appear

# %%
import matplotlib.pyplot as plt
arr = np.random.randint(1, 10, size=(10,2))
print(arr)
plt.scatter(arr[:,0],arr[:,1])
# Out:
# [[6 6]
#  [4 5]
#  [7 2]
#  [4 1]
#  [7 1]
#  [7 5]
#  [9 4]
#  [3 6]
#  [6 5]
#  [9 9]]

# %%
import pandas as pd
df = pd.read_csv('coords.csv')
df = df[1:20]
plt.scatter(df['X'],df['Y'])

# %% [markdown]
# Miscellaneous

# %%
a = [1, 2, 'x', 2, 'y', 'x']
i = 0
while (i<len(a)):
    if a[i] in a[0:i]:
        a.pop(i)
    else:
        i += 1
print(a)

# %%
import math
def isPrime(n):
    for j in range(2,int(math.sqrt(n))+1):
        if(n%j==0):
            return False
    return True

plist = []

for i in range(2,101):
    if (isPrime(i)):
        plist.append(i)
print(plist)

# %% [markdown]
# # Python OOP

# %%
class Employee:
  emp_num = 0 # works like static variable common to all objects of a class

  def __init__(self, first, last, pay):
    self.first = first
    self.last = last
    self.email = first + '.' + last + '@email.com'
    self.pay = pay
    Employee.emp_num += 1

  def fullname(self):
    return f'{self.first} {self.last}'
  
  def applyRaise(self, raise_):
    self.pay = int(self.pay * raise_)

  def __str__(self):
    return f'{self.fullname()} - {self.email}'

  @staticmethod # (Decorator) same working procedure for all objects of a class 
  def is_holiday(day):
    holidays = [1, 30, 49, 350]
    if day in holidays:
        return True
    else:
      return False


print(Employee.emp_num)

emp_1 = Employee('Corey', 'Schafer', 50000)
emp_2 = Employee('Test', 'Employee', 60000)

print(Employee.emp_num)

print(emp_1.fullname())

emp_1.applyRaise(1.05)
print(emp_1.pay)

print(Employee.is_holiday(30))
print(Employee.is_holiday(31))

print(emp_1)
