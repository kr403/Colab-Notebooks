# %%
while True:
    print("Press '1' for Validate UIU CSE ID")
    print("Press '2' for Validate UIU CSE and EEE email address")
    print("Press '3' for Validate a password")
    print("Press '4' for Validate a number")
    print("Press '5' for Validate a string")
    print("Press '6' for Exit")
    option = input()
    if option == '5':
        string()
    if option == '4':
        number()
    if option == '3':
        password()
    if option == '2':
        email()
    if option == '1':
        id()
    if option == '6':
       break
print("Thank you. See you, again...")
# Out:
# Press '1' for Validate UIU CSE ID
# Press '2' for Validate UIU CSE and EEE email address
# Press '3' for Validate a password
# Press '4' for Validate a number
# Press '5' for Validate a string
# Press '6' for Exit
# 5
# Enter a string: khalidUIU1cse
# Not Valid
# Press '1' for Validate UIU CSE ID
# Press '2' for Validate UIU CSE and EEE email address
# Press '3' for Validate a password
# Press '4' for Validate a number
# Press '5' for Validate a string
# Press '6' for Exit
# 6
# Thank you. See you, again...

# %% [markdown]
# #1

# %%
def id():
    iid = input("Enter the id: ")
    if len(iid) == 9:
        if iid[0] == '0':
            if iid[1] == '1':
                if iid[2] == '1':
                    if '0' <= iid[3] <= '2':
                        if '0' <= iid[4] <= '9':
                            if '1' <= iid[5] <= '3':
                                if iid[6] == '0':
                                    if iid[7] == '0':
                                        if iid[8] == '0':
                                            print("Not Valid")
                                        else:
                                            if '0' <= iid[6] <= '9':
                                                if '0' <= iid[7] <= '9':
                                                    if '0' <= iid[8] <= '9':
                                                        print("Valid")
                                                    else:
                                                        print("Not Valid")
                                                else:
                                                    print("Not Valid")
                                            else:
                                                print("Not Valid")
                                    else:
                                        if '0' <= iid[6] <= '9':
                                            if '0' <= iid[7] <= '9':
                                                if '0' <= iid[8] <= '9':
                                                    print("Valid")
                                                else:
                                                    print("Not Valid")
                                            else:
                                                print("Not Valid")
                                        else:
                                            print("Not Valid")
                                else:
                                    if '0' <= iid[6] <= '9':
                                        if '0' <= iid[7] <= '9':
                                            if '0' <= iid[8] <= '9':
                                                print("Valid")
                                            else:
                                                print("Not Valid")
                                        else:
                                            print("Not Valid")
                                    else:
                                        print("Not Valid")
                            else:
                                print("Not Valid")
                        else:
                            print("Not Valid")
                    else:
                        print("Not Valid")
                else:
                    print("Not Valid")
            else:
                print("Not Valid")
        else:
            print("Not Valid")
    else:
        print("Not Valid")

# %% [markdown]
# #2

# %%
def email():
    eid = input("Enter the email: ")
    if eid.find('@') != -1:
        cl = eid.split('@')
        fl = cl[0]
        if len(fl) > 5:      
            x = len(eid)
            count = -1
            if eid.find("@bscse.uiu.ac.bd") == -1:
                if eid.find("@bseee.uiu.ac.bd") == -1:
                    print("Not Valid")
                else:
                    for i in range(x):
                        count = count + 1
                        if '0' <= eid[count] <= '9':
                            break
                    if '0' <= eid[count] <= '2':
                        if '0' <= eid[count + 1] <= '9':
                            if '1' <= eid[count + 2] <= '3':
                                if eid[count + 3] == '0':
                                    if eid[count + 4] == '0':
                                        if eid[count + 5] == '0':
                                            print("Not Valid")
                                        else:
                                            if '0' <= eid[count + 3] <= '9':
                                                if '0' <= eid[count + 4] <= '9':
                                                    if '0' <= eid[count + 5] <= '9':
                                                        print("Valid")
                                                    else:
                                                        print("Not Valid")
                                                else:
                                                    print("Not Valid")
                                            else:
                                                print("Not Valid")
                                    else:
                                        if '0' <= eid[count + 3] <= '9':
                                            if '0' <= eid[count + 4] <= '9':
                                                if '0' <= eid[count + 5] <= '9':
                                                    print("Valid")
                                                else:
                                                    print("Not Valid")
                                            else:
                                                print("Not Valid")
                                        else:
                                            print("Not Valid")
                                else:
                                    if '0' <= eid[count + 3] <= '9':
                                        if '0' <= eid[count + 4] <= '9':
                                            if '0' <= eid[count + 5] <= '9':
                                                print("Valid")
                                            else:
                                                print("Not Valid")
                                        else:
                                            print("Not Valid")
                                    else:
                                        print("Not Valid")
                            else:
                                print("Not Valid")
                        else:
                            print("Not Valid")
                    else:
                        print("Not Valid")
            else:
                for i in range(x):
                    count = count + 1
                    if '0' <= eid[count] <= '9':
                        break
                if '0' <= eid[count] <= '2':
                    if '0' <= eid[count + 1] <= '9':
                        if '1' <= eid[count + 2] <= '3':
                            if eid[count + 3] == '0':
                                if eid[count + 4] == '0':
                                    if eid[count + 5] == '0':
                                        print("Not Valid")
                                    else:
                                        if '0' <= eid[count + 3] <= '9':
                                            if '0' <= eid[count + 4] <= '9':
                                                if '0' <= eid[count + 5] <= '9':
                                                    print("Valid")
                                                else:
                                                    print("Not Valid")
                                            else:
                                                print("Not Valid")
                                        else:
                                            print("Not Valid")
                                else:
                                    if '0' <= eid[count + 3] <= '9':
                                        if '0' <= eid[count + 4] <= '9':
                                            if '0' <= eid[count + 5] <= '9':
                                                print("Valid")
                                            else:
                                                print("Not Valid")
                                        else:
                                            print("Not Valid")
                                    else:
                                        print("Not Valid")
                            else:
                                if '0' <= eid[count + 3] <= '9':
                                    if '0' <= eid[count + 4] <= '9':
                                        if '0' <= eid[count + 5] <= '9':
                                            print("Valid")
                                        else:
                                            print("Not Valid")
                                    else:
                                        print("Not Valid")
                                else:
                                    print("Not Valid")
                        else:
                            print("Not Valid")
                    else:
                        print("Not Valid")
                else:
                    print("Not Valid")
        else:
            print("Not Valid")
    else:
        print("Not Valid")

# %% [markdown]
# #3

# %%
def password():
    p = input("Enter the password: ")
    f = 0
    if len(p) > 7:
        flag = 0
        for i in p:
            if i.isupper():
                if i.lower():
                    flag = 1
                    break
        if flag == 0:
            print("Not Valid")
        if flag == 1:
            flag = 0
            for i in p:
                if i.isnumeric():
                    flag = 1
        else:
            print("Not Valid")
        if flag == 1:
            flag = 0
            for i in p:
                if i.isnumeric() == False:
                    if i.isalpha() == False:    
                        if i == '@':
                            flag = 1
                        if i == '#':
                            flag = 1
                        if i == '%':
                            flag = 1
                        if i == '&':
                            flag = 1
                        if flag != 1:
                            flage = -1
                            break
        else:
            print("Not Valid")
        if flag == 1:
            if p[-1] == 'P':
                print("Valid")
            else:
                print("Not Valid")
        else:
            print("Not Valid")
    else:
        print("Not Valid")

# %% [markdown]
# #4

# %%
def cf(pf):
    try:
        float(pf)
        return True
    except ValueError:
        return False
def number():
    n = input("Enter a number: ")
    s = cf(n)
    if s == True:
        print("Valid")
    else:
        print("Not Valid")

# %% [markdown]
# #5

# %%
def string():
    txt = input("Enter a string: ")
    j = 0
    flag = 0
    if txt[0].islower() == True:
        for i in txt:
            if i.isnumeric() == True:
                flag = 1
        if flag == 1:
            if txt.find('UIU') != -1:
                x = txt.split("UIU")
                x1 = x[0][::-1]
                x2 = x[1][::-1]
                for i,e in enumerate(x1):
                    if x2[i] == e:
                        j += 1
                    else:
                        break
                if j== len(x1):
                    print("Valid")
                else:
                    print("Not Valid")
            else:
                print("Not Valid")
        else:
            print("Not Valid")
    else:
        print("Not Valid")
